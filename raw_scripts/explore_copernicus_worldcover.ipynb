# %% [markdown]
# # Exploring Copernicus DEM elevation data

# %%
import pystac_client
url = "https://stac.dataspace.copernicus.eu/v1"
catalog = pystac_client.Client.open(url)

#search = catalog.collection_search(q='worldcover')
for item in catalog.get_collections():
    print(item.title, item)
# Out:
# Copernicus Contributing Missions Optical <CollectionClient id=ccm-optical>
# Copernicus Contributing Missions SAR <CollectionClient id=ccm-sar>
# CLMS BA Global 300m daily V3 (COG) <CollectionClient id=clms_ba_global_300m_daily_v3_cog>
# CLMS BA Global 300m daily V3 (NetCDF) <CollectionClient id=clms_ba_global_300m_daily_v3_nc>
# CLMS BA Global 300m daily V4 (COG) <CollectionClient id=clms_ba_global_300m_daily_v4_cog>
# CLMS BA Global 300m daily V4 (NetCDF) <CollectionClient id=clms_ba_global_300m_daily_v4_nc>
# CLMS BA Global 300m monthly V3 (COG) <CollectionClient id=clms_ba_global_300m_monthly_v3_cog>
# CLMS BA Global 300m monthly V3 (NetCDF) <CollectionClient id=clms_ba_global_300m_monthly_v3_nc>
# CLMS BA Global 300m monthly V4 (COG) <CollectionClient id=clms_ba_global_300m_monthly_v4_cog>
# CLMS BA Global 300m monthly V4 (NetCDF) <CollectionClient id=clms_ba_global_300m_monthly_v4_nc>
# CLMS DMP Global 1km 10-daily V2 (COG) <CollectionClient id=clms_dmp_global_1km_10daily_v2_cog>
# CLMS DMP Global 1km 10-daily V2 (NetCDF) <CollectionClient id=clms_dmp_global_1km_10daily_v2_nc>
# CLMS DMP Global 300m 10-daily V1 (COG) <CollectionClient id=clms_dmp_global_300m_10daily_v1_cog>
# CLMS DMP Global 300m 10-daily V1 (NetCDF) <CollectionClient id=clms_dmp_global_300m_10daily_v1_nc>
# CLMS DMP Global 300m 10-daily V2 (COG) <CollectionClient id=clms_dmp_global_300m_10daily_v2_cog>
# CLMS DMP Global 300m 10-daily V2 (NetCDF) <CollectionClient id=clms_dmp_global_300m_10daily_v2_nc>
# CLMS ETA Global 300m 10-daily V1 (COG) <CollectionClient id=clms_eta_global_300m_10daily_v1_cog>
# CLMS GDMP Global 1km 10-daily V2 (COG) <CollectionClient id=clms_gdmp_global_1km_10daily_v2_cog>
# CLMS GDMP Global 1km 10-daily V2 (NetCDF) <CollectionClient id=clms_gdmp_global_1km_10daily_v2_nc>
# CLMS GDMP Global 300m 10-daily V1 (COG) <CollectionClient id=clms_gdmp_global_300m_10daily_v1_cog>
# CLMS GDMP Global 300m 10-daily V1 (NetCDF) <CollectionClient id=clms_gdmp_global_300m_10daily_v1_nc>
# CLMS GDMP Global 300m 10-daily V2 (COG) <CollectionClient id=clms_gdmp_global_300m_10daily_v2_cog>
# CLMS GDMP Global 300m 10-daily V2 (NetCDF) <CollectionClient id=clms_gdmp_global_300m_10daily_v2_nc>
# CLMS GPP Global 300m 10-daily V1 (COG) <CollectionClient id=clms_gpp_global_300m_10daily_v1_cog>
# CLMS GPP Global 300m 10-daily V1 (NetCDF) <CollectionClient id=clms_gpp_global_300m_10daily_v1_nc>
# CLMS GPP Global 300m 10-daily V2 (COG) <CollectionClient id=clms_gpp_global_300m_10daily_v2_cog>
# CLMS GPP Global 300m 10-daily V2 (NetCDF) <CollectionClient id=clms_gpp_global_300m_10daily_v2_nc>
# CLMS HF Global 300m daily V1 (COG) <CollectionClient id=clms_hf_global_300m_daily_v1_cog>
# CLMS LC Global 100m yearly V3 (COG) <CollectionClient id=clms_lc_global_100m_yearly_v3_cog>
# CLMS LSWT NRT Global 1km 10-daily V1 (COG) <CollectionClient id=clms_lswt-nrt_global_1km_10daily_v1_cog>
# CLMS LSWT NRT Global 1km 10-daily V1 (NetCDF) <CollectionClient id=clms_lswt-nrt_global_1km_10daily_v1_nc>
# CLMS LSWT Offline Global 1km 10-daily V1 (COG) <CollectionClient id=clms_lswt-offline_global_1km_10daily_v1_cog>
# CLMS LSWT Offline Global 1km 10-daily V1 (NetCDF) <CollectionClient id=clms_lswt-offline_global_1km_10daily_v1_nc>
# CLMS LWQ NRT Global 100m 10-daily V1 (COG) <CollectionClient id=clms_lwq-nrt_global_100m_10daily_v1_cog>
# CLMS LWQ NRT Global 100m 10-daily V1 (NetCDF) <CollectionClient id=clms_lwq-nrt_global_100m_10daily_v1_nc>
# CLMS LWQ NRT Global 100m 10-daily V2 (COG) <CollectionClient id=clms_lwq-nrt_global_100m_10daily_v2_cog>
# CLMS LWQ NRT Global 100m 10-daily V2 (NetCDF) <CollectionClient id=clms_lwq-nrt_global_100m_10daily_v2_nc>
# CLMS LWQ NRT Global 300m 10-daily V1 (COG) <CollectionClient id=clms_lwq-nrt_global_300m_10daily_v1_cog>
# CLMS LWQ NRT Global 300m 10-daily V1 (NetCDF) <CollectionClient id=clms_lwq-nrt_global_300m_10daily_v1_nc>
# CLMS LWQ NRT Global 300m 10-daily V2 (COG) <CollectionClient id=clms_lwq-nrt_global_300m_10daily_v2_cog>
# CLMS LWQ NRT Global 300m 10-daily V2 (NetCDF) <CollectionClient id=clms_lwq-nrt_global_300m_10daily_v2_nc>
# CLMS LWQ Reproc Global 300m 10-daily V1 (COG) <CollectionClient id=clms_lwq-reproc_global_300m_10daily_v1_cog>
# CLMS LWQ Reproc Global 300m 10-daily V1 (NetCDF) <CollectionClient id=clms_lwq-reproc_global_300m_10daily_v1_nc>
# CLMS NDVI Global 300m 10-daily v3 (COG) <CollectionClient id=clms_ndvi_global_300m_10daily_v3_cog>
# CLMS NDVI Global 300m 10-daily V3 (NetCDF) <CollectionClient id=clms_ndvi_global_300m_10daily_v3_nc>
# CLMS NPP Global 300m 10-daily V1 (COG) <CollectionClient id=clms_npp_global_300m_10daily_v1_cog>
# CLMS NPP Global 300m 10-daily V1 (NetCDF) <CollectionClient id=clms_npp_global_300m_10daily_v1_nc>
# CLMS NPP Global 300m 10-daily V2 (COG) <CollectionClient id=clms_npp_global_300m_10daily_v2_cog>
# CLMS NPP Global 300m 10-daily V2 (NetCDF) <CollectionClient id=clms_npp_global_300m_10daily_v2_nc>
# CLMS SSM Europe 1km daily v1 (COG) <CollectionClient id=clms_ssm_europe_1km_daily_v1_cog>
# CLMS SSM Europe 1km daily v1 (NetCDF) <CollectionClient id=clms_ssm_europe_1km_daily_v1_nc>
# CLMS Urban Atlas Building Block Height (BBH) (10m) - Europe <CollectionClient id=clms_ua_building-height_europe_10m_3yearly_v1>
# CLMS Urban Atlas Land Cover and Land Use Change (0.10ha MMU) - Europe <CollectionClient id=clms_urban-atlas_land-cover-use-change_europe_V010ha_vector_static_v01>
# CLMS Urban Atlas Land Cover and Land Use (0.25ha MMU) - Europe <CollectionClient id=clms_urban-atlas_land-cover-use_europe_V025ha_vector_static_v01>
# CLMS Urban Atlas Street Tree Layer (0.05ha MMU) - Europe <CollectionClient id=clms_urban-atlas_street-tree-layer_europe_V005ha_vector_static_v01>
# CopDEM TIFF (10 m) <CollectionClient id=cop-dem-eea-10-laea-tif>
# CopDEM COG (30 m) <CollectionClient id=cop-dem-glo-30-dged-cog>
# CopDEM COG (90 m) <CollectionClient id=cop-dem-glo-90-dged-cog>
# Landsat Collection 2 Level-1 Operational Land Imager <CollectionClient id=landsat-c2-l1-oli>
# Landsat Collection 2 Level-1 Operational Land Imager/Thermal Infrared <CollectionClient id=landsat-c2-l1-oli-tirs>
# Landsat Collection 2 Level-1 Thermal Infared <CollectionClient id=landsat-c2-l1-tirs>
# MODIS Aqua Surface Reflectance 8-Day L3 Global 500m <CollectionClient id=modis-aqua-myd09a1>
# MODIS Aqua Surface Reflectance 8-Day L3 Global 250m <CollectionClient id=modis-aqua-myd09q1>
# MODIS Aqua Snow Cover Daily Global 500m <CollectionClient id=modis-aqua-myd10a1>
# MODIS Aqua Snow Cover 8-Day L3 Global 500m <CollectionClient id=modis-aqua-myd10a2>
# MODIS Aqua Land Surface Temperature Emissivity Daily L3 Global 1km <CollectionClient id=modis-aqua-myd11a1>
# MODIS Aqua Land Surface Temperature Emissivity 8-Day L3 Global 1km <CollectionClient id=modis-aqua-myd11a2>
# MODIS Aqua Vegetation Indices 16-Day L3 Global 500m <CollectionClient id=modis-aqua-myd13a1>
# MODIS Aqua Vegetation Indices 16-Day L3 Global 1km <CollectionClient id=modis-aqua-myd13a2>
# MODIS Aqua Vegetation Indices 16-Day L3 Global 250m <CollectionClient id=modis-aqua-myd13q1>
# MODIS Aqua Thermal Anomalies Fire Daily L3 Global 1km <CollectionClient id=modis-aqua-myd14a1>
# MODIS Aqua Thermal Anomalies Fire 8-Day L3 Global 1km <CollectionClient id=modis-aqua-myd14a2>
# MODIS Aqua Leaf Area Index FPAR 8-Day L4 Global 500m <CollectionClient id=modis-aqua-myd15a2h>
# MODIS Aqua Net Evapotranspiration Gap-Filled Yearly L4 Global 500m <CollectionClient id=modis-aqua-myd16a3gf>
# MODIS Aqua Gross Primary Productivity 8-Day L4 Global 500m <CollectionClient id=modis-aqua-myd17a2h>
# MODIS Aqua Gross Primary Productivity Gap-Filled 8-Day L4 Global 500m <CollectionClient id=modis-aqua-myd17a2hgf>
# MODIS Aqua Net Primary Production Gap-Filled Yearly L4 Global 500m <CollectionClient id=modis-aqua-myd17a3hgf>
# MODIS Aqua Land Surface Temperature 3-Band Emissivity 8-Day L3 Global 1km <CollectionClient id=modis-aqua-myd21a2>
# MODIS Terra Surface Reflectance 8-Day L3 Global 500m <CollectionClient id=modis-terra-mod09a1>
# MODIS Terra Surface Reflectance 8-Day L3 Global 250m <CollectionClient id=modis-terra-mod09q1>
# MODIS Terra Snow Cover Daily Global 500m <CollectionClient id=modis-terra-mod10a1>
# MODIS Terra Snow Cover 8-Day L3 Global 500m <CollectionClient id=modis-terra-mod10a2>
# MODIS Terra Land Surface Temperature Emissivity Daily L3 Global 1km <CollectionClient id=modis-terra-mod11a1>
# MODIS Terra Land Surface Temperature Emissivity 8-Day L3 Global 1km <CollectionClient id=modis-terra-mod11a2>
# MODIS Terra Vegetation Indices 16-Day L3 Global 500m <CollectionClient id=modis-terra-mod13a1>
# MODIS Terra Vegetation Indices 16-Day L3 Global 1km <CollectionClient id=modis-terra-mod13a2>
# MODIS Terra Vegetation Indices 16-Day L3 Global 250m <CollectionClient id=modis-terra-mod13q1>
# MODIS Terra Thermal Anomalies Fire Daily L3 Global 1km <CollectionClient id=modis-terra-mod14a1>
# MODIS Terra Thermal Anomalies Fire 8-Day L3 Global 1km <CollectionClient id=modis-terra-mod14a2>
# MODIS Terra Leaf Area Index FPAR 8-Day L4 Global 500m <CollectionClient id=modis-terra-mod15a2h>
# MODIS Terra Net Evapotranspiration Gap-Filled 8-Day L4 Global 500m <CollectionClient id=modis-terra-mod16a2gf>
# MODIS Terra Net Evapotranspiration Gap-Filled Yearly L4 Global 500m <CollectionClient id=modis-terra-mod16a3gf>
# MODIS Terra Gross Primary Productivity 8-Day L4 Global 500m <CollectionClient id=modis-terra-mod17a2h>
# MODIS Terra Gross Primary Productivity Gap-Filled 8-Day L4 Global 500m <CollectionClient id=modis-terra-mod17a2hgf>
# MODIS Terra Net Primary Production Gap-Filled Yearly L4 Global 500m <CollectionClient id=modis-terra-mod17a3hgf>
# MODIS Terra Land Surface Temperature 3-Band Emissivity 8-Day L3 Global 1km <CollectionClient id=modis-terra-mod21a2>
# MODIS Terra and Aqua Land Cover Type Yearly Global 500m <CollectionClient id=modis-terraaqua-mcd12q1>
# MODIS Terra and Aqua Leaf Area Index FPAR 8-Day L4 Global 500m <CollectionClient id=modis-terraaqua-mcd15a2h>
# MODIS Terra and Aqua Leaf Area Index FPAR 4-Day L4 Global 500m <CollectionClient id=modis-terraaqua-mcd15a3h>
# MODIS Terra and Aqua BRDF Albedo Nadir BRDF-Adjusted Reflectance Daily L3 Global 500m <CollectionClient id=modis-terraaqua-mcd43a4>
# MODIS Terra and Aqua Direct Broadcast Burned Area Monthly L3 Global 500m <CollectionClient id=modis-terraaqua-mcd64a1>
# Landsat mosaic (bi-monthly, v1.0.1) <CollectionClient id=opengeohub-landsat-bimonthly-mosaic-v1.0.1>
# Sentinel-1 Extended Time Annotation Products (ETAD)  <CollectionClient id=sentinel-1-etad>
# Sentinel-1 Global Mosaics <CollectionClient id=sentinel-1-global-mosaics>
# Sentinel-1 Ground Range Detected (GRD) <CollectionClient id=sentinel-1-grd>
# Sentinel-1 Level-2 Ocean (OCN): IW, EW, SM <CollectionClient id=sentinel-1-ocn>
# Sentinel-1 Level-2 Ocean (OCN): WV <CollectionClient id=sentinel-1-ocn-wv>
# Sentinel-1 Single Look Complex: IW, EW, SM <CollectionClient id=sentinel-1-slc>
# Sentinel-1 Single Look Complex: WV <CollectionClient id=sentinel-1-slc-wv>
# Sentinel-2 Global Mosaics <CollectionClient id=sentinel-2-global-mosaics>
# Sentinel-2 GRI L1C <CollectionClient id=sentinel-2-gri-l1c>
# Sentinel-2 GRI L1C GCP <CollectionClient id=sentinel-2-gri-l1c-gcp>
# Sentinel-2 Level-1C <CollectionClient id=sentinel-2-l1c>
# Sentinel-2 Level-2A <CollectionClient id=sentinel-2-l2a>
# Sentinel-3 OLCI Earth Observation Full Resolution (NRT) <CollectionClient id=sentinel-3-olci-1-efr-nrt>
# Sentinel-3 OLCI Earth Observation Full Resolution (NTC) <CollectionClient id=sentinel-3-olci-1-efr-ntc>
# Sentinel-3 OLCI Earth Observation Reduced Resolution (NRT) <CollectionClient id=sentinel-3-olci-1-err-nrt>
# Sentinel-3 OLCI Earth Observation Reduced Resolution (NTC) <CollectionClient id=sentinel-3-olci-1-err-ntc>
# Sentinel-3 OLCI Land Full Resolution (NRT) <CollectionClient id=sentinel-3-olci-2-lfr-nrt>
# Sentinel-3 OLCI Land Full Resolution (NTC) <CollectionClient id=sentinel-3-olci-2-lfr-ntc>
# Sentinel-3 OLCI Land Reduced Resolution (NRT) <CollectionClient id=sentinel-3-olci-2-lrr-nrt>
# Sentinel-3 OLCI Land Reduced Resolution (NTC) <CollectionClient id=sentinel-3-olci-2-lrr-ntc>
# Sentinel-3 OLCI Water Full Resolution (NRT) <CollectionClient id=sentinel-3-olci-2-wfr-nrt>
# Sentinel-3 OLCI Water Full Resolution (NTC) <CollectionClient id=sentinel-3-olci-2-wfr-ntc>
# Sentinel-3 OLCI Water Reduced Resolution (NRT) <CollectionClient id=sentinel-3-olci-2-wrr-nrt>
# Sentinel-3 OLCI Water Reduced Resolution (NTC) <CollectionClient id=sentinel-3-olci-2-wrr-ntc>
# Sentinel-3 SLSTR Radiance and Brightness Temperature (NRT) <CollectionClient id=sentinel-3-sl-1-rbt-nrt>
# Sentinel-3 SLSTR Radiance and Brightness Temperature (NTC) <CollectionClient id=sentinel-3-sl-1-rbt-ntc>
# Sentinel-3 SLSTR Aerosol Optical Depth (NRT) <CollectionClient id=sentinel-3-sl-2-aod-nrt>
# Sentinel-3 SLSTR Fire Radiative Power (NRT) <CollectionClient id=sentinel-3-sl-2-frp-nrt>
# Sentinel-3 SLSTR Fire Radiative Power (NTC) <CollectionClient id=sentinel-3-sl-2-frp-ntc>
# Sentinel-3 SLSTR Land Surface Temperature (NRT) <CollectionClient id=sentinel-3-sl-2-lst-nrt>
# Sentinel-3 SLSTR Land Surface Temperature (NTC) <CollectionClient id=sentinel-3-sl-2-lst-ntc>
# Sentinel-3 SLSTR Water Surface Temperature (NRT) <CollectionClient id=sentinel-3-sl-2-wst-nrt>
# Sentinel-3 SLSTR Water Surface Temperature (NTC) <CollectionClient id=sentinel-3-sl-2-wst-ntc>
# Sentinel-3 SRAL Radar Altimetry L-1A (NRT) <CollectionClient id=sentinel-3-sr-1-sra-a-nrt>
# Sentinel-3 SRAL Radar Altimetry L-1A (NTC) <CollectionClient id=sentinel-3-sr-1-sra-a-ntc>
# Sentinel-3 SRAL Radar Altimetry L-1A (STC) <CollectionClient id=sentinel-3-sr-1-sra-a-stc>
# Sentinel-3 SRAL Radar Altimetry L-1B (NRT) <CollectionClient id=sentinel-3-sr-1-sra-nrt>
# Sentinel-3 SRAL Radar Altimetry L-1B (NTC) <CollectionClient id=sentinel-3-sr-1-sra-ntc>
# Sentinel-3 SRAL Radar Altimetry L-1B (STC) <CollectionClient id=sentinel-3-sr-1-sra-stc>
# Sentinel-3 SRAL Land Radar Altimetry - Hydrology (NRT) <CollectionClient id=sentinel-3-sr-2-lan-hy-nrt>
# Sentinel-3 SRAL Land Radar Altimetry - Hydrology (NTC) <CollectionClient id=sentinel-3-sr-2-lan-hy-ntc>
# Sentinel-3 SRAL Land Radar Altimetry - Hydrology (STC) <CollectionClient id=sentinel-3-sr-2-lan-hy-stc>
# Sentinel-3 SRAL Land Radar Altimetry - Land Ice (NRT) <CollectionClient id=sentinel-3-sr-2-lan-li-nrt>
# Sentinel-3 SRAL Land Radar Altimetry - Land Ice (NTC) <CollectionClient id=sentinel-3-sr-2-lan-li-ntc>
# Sentinel-3 SRAL Land Radar Altimetry - Land Ice (STC) <CollectionClient id=sentinel-3-sr-2-lan-li-stc>
# Sentinel-3 SRAL Land Radar Altimetry (NRT) <CollectionClient id=sentinel-3-sr-2-lan-nrt>
# Sentinel-3 SRAL Land Radar Altimetry (NTC) <CollectionClient id=sentinel-3-sr-2-lan-ntc>
# Sentinel-3 SRAL Land Radar Altimetry - Sea Ice (NRT) <CollectionClient id=sentinel-3-sr-2-lan-si-nrt>
# Sentinel-3 SRAL Land Radar Altimetry - Sea Ice (NTC) <CollectionClient id=sentinel-3-sr-2-lan-si-ntc>
# Sentinel-3 SRAL Land Radar Altimetry - Sea Ice (STC) <CollectionClient id=sentinel-3-sr-2-lan-si-stc>
# Sentinel-3 SRAL Land Radar Altimetry (STC) <CollectionClient id=sentinel-3-sr-2-lan-stc>
# Sentinel-3 SRAL Ocean Radar Altimetry (NRT) <CollectionClient id=sentinel-3-sr-2-wat-nrt>
# Sentinel-3 SRAL Ocean Radar Altimetry (NTC) <CollectionClient id=sentinel-3-sr-2-wat-ntc>
# Sentinel-3 SRAL Ocean Radar Altimetry (STC) <CollectionClient id=sentinel-3-sr-2-wat-stc>
# Sentinel-3 SYNERGY Aerosol Optical Depth (NTC) <CollectionClient id=sentinel-3-syn-2-aod-ntc>
# Sentinel-3 Land Surface Reflectance and Aerosol (NTC) <CollectionClient id=sentinel-3-syn-2-syn-ntc>
# Sentinel-3 Land Surface Reflectance and Aerosol (STC) <CollectionClient id=sentinel-3-syn-2-syn-stc>
# Sentinel-3 SYNERGY 10-Day Surface Reflectance and NDVI (NTC) <CollectionClient id=sentinel-3-syn-2-v10-ntc>
# Sentinel-3 SYNERGY 10-Day Surface Reflectance and NDVI (STC) <CollectionClient id=sentinel-3-syn-2-v10-stc>
# Sentinel-3 SYNERGY 1-Day Surface Reflectance and NDVI (NTC) <CollectionClient id=sentinel-3-syn-2-vg1-ntc>
# Sentinel-3 SYNERGY 1-Day Surface Reflectance and NDVI (STC) <CollectionClient id=sentinel-3-syn-2-vg1-stc>
# Sentinel-3 SYNERGY Top of Atmosphere Reflectance (NTC) <CollectionClient id=sentinel-3-syn-2-vgp-ntc>
# Sentinel-3 SYNERGY Top of Atmosphere Reflectance (STC) <CollectionClient id=sentinel-3-syn-2-vgp-stc>
# Sentinel-5P Level 1 Radiance Band 1 (NRTI) <CollectionClient id=sentinel-5p-l1-ra-bd1-nrti>
# Sentinel-5P Level 1 Radiance Band 1 (OFFL) <CollectionClient id=sentinel-5p-l1-ra-bd1-offl>
# Sentinel-5P Level 1 Radiance Band 1 (RPRO) <CollectionClient id=sentinel-5p-l1-ra-bd1-rpro>
# Sentinel-5P Level 1 Radiance Band 2 (NRTI) <CollectionClient id=sentinel-5p-l1-ra-bd2-nrti>
# Sentinel-5P Level 1 Radiance Band 2 (OFFL) <CollectionClient id=sentinel-5p-l1-ra-bd2-offl>
# Sentinel-5P Level 1 Radiance Band 2 (RPRO) <CollectionClient id=sentinel-5p-l1-ra-bd2-rpro>
# Sentinel-5P Level 1 Radiance Band 3 (NRTI) <CollectionClient id=sentinel-5p-l1-ra-bd3-nrti>
# Sentinel-5P Level 1 Radiance Band 3 (OFFL) <CollectionClient id=sentinel-5p-l1-ra-bd3-offl>
# Sentinel-5P Level 1 Radiance Band 3 (RPRO) <CollectionClient id=sentinel-5p-l1-ra-bd3-rpro>
# Sentinel-5P Level 1 Radiance Band 4 (NRTI) <CollectionClient id=sentinel-5p-l1-ra-bd4-nrti>
# Sentinel-5P Level 1 Radiance Band 4 (OFFL) <CollectionClient id=sentinel-5p-l1-ra-bd4-offl>
# Sentinel-5P Level 1 Radiance Band 4 (RPRO) <CollectionClient id=sentinel-5p-l1-ra-bd4-rpro>
# Sentinel-5P Level 1 Radiance Band 5 (NRTI) <CollectionClient id=sentinel-5p-l1-ra-bd5-nrti>
# Sentinel-5P Level 1 Radiance Band 5 (OFFL) <CollectionClient id=sentinel-5p-l1-ra-bd5-offl>
# Sentinel-5P Level 1 Radiance Band 5 (RPRO) <CollectionClient id=sentinel-5p-l1-ra-bd5-rpro>
# Sentinel-5P Level 1 Radiance Band 6 (NRTI) <CollectionClient id=sentinel-5p-l1-ra-bd6-nrti>
# Sentinel-5P Level 1 Radiance Band 6 (OFFL) <CollectionClient id=sentinel-5p-l1-ra-bd6-offl>
# Sentinel-5P Level 1 Radiance Band 6 (RPRO) <CollectionClient id=sentinel-5p-l1-ra-bd6-rpro>
# Sentinel-5P Level 1 Radiance Band 7 (NRTI) <CollectionClient id=sentinel-5p-l1-ra-bd7-nrti>
# Sentinel-5P Level 1 Radiance Band 7 (OFFL) <CollectionClient id=sentinel-5p-l1-ra-bd7-offl>
# Sentinel-5P Level 1 Radiance Band 7 (RPRO) <CollectionClient id=sentinel-5p-l1-ra-bd7-rpro>
# Sentinel-5P Level 1 Radiance Band 8 (NRTI) <CollectionClient id=sentinel-5p-l1-ra-bd8-nrti>
# Sentinel-5P Level 1 Radiance Band 8 (OFFL) <CollectionClient id=sentinel-5p-l1-ra-bd8-offl>
# Sentinel-5P Level 1 Radiance Band 8 (RPRO) <CollectionClient id=sentinel-5p-l1-ra-bd8-rpro>
# Sentinel-5P Level 2 Ultraviolet Aerosol Index (NRTI) <CollectionClient id=sentinel-5p-l2-aer-ai-nrti>
# Sentinel-5P Level 2 Ultraviolet Aerosol Index (OFFL) <CollectionClient id=sentinel-5p-l2-aer-ai-offl>
# Sentinel-5P Level 2 Ultraviolet Aerosol Index (RPRO) <CollectionClient id=sentinel-5p-l2-aer-ai-rpro>
# Sentinel-5P Level 2 Aerosol Layer Height (NRTI) <CollectionClient id=sentinel-5p-l2-aer-lh-nrti>
# Sentinel-5P Level 2 Aerosol Layer Height (OFFL) <CollectionClient id=sentinel-5p-l2-aer-lh-offl>
# Sentinel-5P Level 2 Aerosol Layer Height (RPRO) <CollectionClient id=sentinel-5p-l2-aer-lh-rpro>
# Sentinel-5P Level 2 Methane (NRTI) <CollectionClient id=sentinel-5p-l2-ch4-nrti>
# Sentinel-5P Level 2 Methane (OFFL) <CollectionClient id=sentinel-5p-l2-ch4-offl>
# Sentinel-5P Level 2 Methane (RPRO) <CollectionClient id=sentinel-5p-l2-ch4-rpro>
# Sentinel-5P Level 2 Cloud (NRTI) <CollectionClient id=sentinel-5p-l2-cloud-nrti>
# Sentinel-5P Level 2 Cloud (OFFL) <CollectionClient id=sentinel-5p-l2-cloud-offl>
# Sentinel-5P Level 2 Cloud (RPRO) <CollectionClient id=sentinel-5p-l2-cloud-rpro>
# Sentinel-5P Level 2 Carbon Monoxide (NRTI) <CollectionClient id=sentinel-5p-l2-co-nrti>
# Sentinel-5P Level 2 Carbon Monoxide (OFFL) <CollectionClient id=sentinel-5p-l2-co-offl>
# Sentinel-5P Level 2 Carbon Monoxide (RPRO) <CollectionClient id=sentinel-5p-l2-co-rpro>
# Sentinel-5P Level 2 Formaldehyde (NRTI) <CollectionClient id=sentinel-5p-l2-hcho-nrti>
# Sentinel-5P Level 2 Formaldehyde (OFFL) <CollectionClient id=sentinel-5p-l2-hcho-offl>
# Sentinel-5P Level 2 Formaldehyde (RPRO) <CollectionClient id=sentinel-5p-l2-hcho-rpro>
# Sentinel-5P Level 2 Nitrogen Dioxide (NRTI) <CollectionClient id=sentinel-5p-l2-no2-nrti>
# Sentinel-5P Level 2 Nitrogen Dioxide (OFFL) <CollectionClient id=sentinel-5p-l2-no2-offl>
# Sentinel-5P Level 2 Nitrogen Dioxide (RPRO) <CollectionClient id=sentinel-5p-l2-no2-rpro>
# Sentinel-5P Level 2 NPP Cloud (band 3) (OFFL) <CollectionClient id=sentinel-5p-l2-np-bd3-offl>
# Sentinel-5P Level 2 NPP Cloud (band 3) (RPRO) <CollectionClient id=sentinel-5p-l2-np-bd3-rpro>
# Sentinel-5P Level 2 NPP Cloud (band 6) (OFFL) <CollectionClient id=sentinel-5p-l2-np-bd6-offl>
# Sentinel-5P Level 2 NPP Cloud (band 6) (RPRO) <CollectionClient id=sentinel-5p-l2-np-bd6-rpro>
# Sentinel-5P Level 2 NPP Cloud (band 7) (OFFL) <CollectionClient id=sentinel-5p-l2-np-bd7-offl>
# Sentinel-5P Level 2 NPP Cloud (band 7) (RPRO) <CollectionClient id=sentinel-5p-l2-np-bd7-rpro>
# Sentinel-5P Level 2 Ozone (NRTI) <CollectionClient id=sentinel-5p-l2-o3-nrti>
# Sentinel-5P Level 2 Ozone (OFFL) <CollectionClient id=sentinel-5p-l2-o3-offl>
# Sentinel-5P Level 2 Ozone Profile (NRTI) <CollectionClient id=sentinel-5p-l2-o3-pr-nrti>
# Sentinel-5P Level 2 Ozone Profile (OFFL) <CollectionClient id=sentinel-5p-l2-o3-pr-offl>
# Sentinel-5P Level 2 Ozone Profile (RPRO) <CollectionClient id=sentinel-5p-l2-o3-pr-rpro>
# Sentinel-5P Level 2 Ozone (RPRO) <CollectionClient id=sentinel-5p-l2-o3-rpro>
# Sentinel-5P Level 2 Tropospheric Ozone (NRTI) <CollectionClient id=sentinel-5p-l2-o3-tcl-nrti>
# Sentinel-5P Level 2 Tropospheric Ozone (OFFL) <CollectionClient id=sentinel-5p-l2-o3-tcl-offl>
# Sentinel-5P Level 2 Tropospheric Ozone (RPRO) <CollectionClient id=sentinel-5p-l2-o3-tcl-rpro>
# Sentinel-5P Level 2 Sulphur Dioxide (NRTI) <CollectionClient id=sentinel-5p-l2-so2-nrti>
# Sentinel-5P Level 2 Sulphur Dioxide (OFFL) <CollectionClient id=sentinel-5p-l2-so2-offl>
# Sentinel-5P Level 2 Sulphur Dioxide (RPRO) <CollectionClient id=sentinel-5p-l2-so2-rpro>
# Sentinel-6 AMR-C Near Real-Time (NRT) <CollectionClient id=sentinel-6-amr-c-nrt>
# Sentinel-6 AMR-C Non Time Critical (NTC) <CollectionClient id=sentinel-6-amr-c-ntc>
# Sentinel-6 AMR-C Short Time Critical (STC) <CollectionClient id=sentinel-6-amr-c-stc>
# Sentinel-6 P4 Level 1B Near Real-Time (NRT) <CollectionClient id=sentinel-6-p4-1b-nrt>
# Sentinel-6 P4 Level 1B Non Time Critical (NTC) <CollectionClient id=sentinel-6-p4-1b-ntc>
# Sentinel-6 P4 Level 1B Short Time Critical (STC) <CollectionClient id=sentinel-6-p4-1b-stc>
# Sentinel-6 P4 Level 2 Near Real-Time (NRT) <CollectionClient id=sentinel-6-p4-2-nrt>
# Sentinel-6 P4 Level 2 Non Time Critical (NTC) <CollectionClient id=sentinel-6-p4-2-ntc>
# Sentinel-6 P4 Level 2 Short Time Critical (STC) <CollectionClient id=sentinel-6-p4-2-stc>

# %%
search = catalog.search(
    collections=["cop-dem-glo-30-dged-cog"],
    bbox=[10, 59, 11+1, 60+1],  # example: Oslo-ish
    #limit=10
)

for item in search.items():
    print(item)

# %%
item.assets
# Out:
# {'data': <Asset href=s3://eodata/auxdata/CopDEM_COG/copernicus-dem-30m/Copernicus_DSM_COG_10_N58_00_E011_00_DEM/Copernicus_DSM_COG_10_N58_00_E011_00_DEM.tif>,
#  'manifest': <Asset href=s3://eodata/auxdata/CopDEM_COG/copernicus-dem-30m/Copernicus_DSM_COG_10_N58_00_E011_00_DEM/Copernicus_DSM_10_N58_00_E011_00.xml>}

# %%
item.assets['data'].href
# Out:
# 's3://eodata/auxdata/CopDEM_COG/copernicus-dem-30m/Copernicus_DSM_COG_10_N58_00_E011_00_DEM/Copernicus_DSM_COG_10_N58_00_E011_00_DEM.tif'

# %%
import xarray as xr
import rioxarray
import fsspec

COPERNICUS_S3_ACCESS_KEY = 'P9CHZ43WR54PNJVOFJXT'
COPERNICUS_S3_SECRET_KEY = 'OReOJAn8hLxqh5cQjkn0AwFV6BZcHSG7fVSpMvps'

fs = fsspec.filesystem(
    "s3",
    client_kwargs={"endpoint_url": "https://eodata.dataspace.copernicus.eu"},
    key=COPERNICUS_S3_ACCESS_KEY,
    secret=COPERNICUS_S3_SECRET_KEY,
)

pth = item.assets['data'].href.replace("s3://", "")

with fs.open(pth, "rb") as f:
    ds = rioxarray.open_rasterio(f)
ds
# Out:
# Exception ignored in: <function CachingFileManager.__del__ at 0x00000187F867FEC0>
# Traceback (most recent call last):
#   File "c:\Users\karimba\Documents\Github\chap-GIS\.venv\Lib\site-packages\xarray\backends\file_manager.py", line 252, in __del__
#     ref_count = self._ref_counter.decrement(self._key)
# AttributeError: 'CachingFileManager' object has no attribute '_ref_counter'
# Exception ignored in: <function CachingFileManager.__del__ at 0x00000187F867FEC0>
# Traceback (most recent call last):
#   File "c:\Users\karimba\Documents\Github\chap-GIS\.venv\Lib\site-packages\xarray\backends\file_manager.py", line 252, in __del__
#     ref_count = self._ref_counter.decrement(self._key)
# AttributeError: 'CachingFileManager' object has no attribute '_ref_counter'
# Exception ignored in: <function CachingFileManager.__del__ at 0x00000187F867FEC0>
# Traceback (most recent call last):
#   File "c:\Users\karimba\Documents\Github\chap-GIS\.venv\Lib\site-packages\xarray\backends\file_manager.py", line 252, in __del__
#     ref_count = self._ref_counter.decrement(self._key)
# AttributeError: 'CachingFileManager' object has no attribute '_ref_counter'
# Exception ignored in: <function CachingFileManager.__del__ at 0x00000187F867FEC0>
# Traceback (most recent call last):
#   File "c:\Users\karimba\Documents\Github\chap-GIS\.venv\Lib\site-packages\xarray\backends\file_manager.py", line 252, in __del__
#     ref_count = self._ref_counter.decrement(self._key)
# AttributeError: 'CachingFileManager' object has no attribute '_ref_counter'
# <xarray.DataArray (band: 1, y: 3600, x: 2400)> Size: 35MB
# [8640000 values with dtype=float32]
# Coordinates:
#   * band         (band) int64 8B 1
#   * y            (y) float64 29kB 59.0 59.0 59.0 59.0 ... 58.0 58.0 58.0 58.0
#   * x            (x) float64 19kB 11.0 11.0 11.0 11.0 ... 12.0 12.0 12.0 12.0
#     spatial_ref  int64 8B 0
# Attributes:
#     AREA_OR_POINT:  Point
#     scale_factor:   1.0
#     add_offset:     0.0

# %%
ds.plot()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 ds.plot()
#
# File c:\Users\karimba\Documents\Github\chap-GIS\.venv\Lib\site-packages\xarray\plot\accessor.py:48, in DataArrayPlotAccessor.__call__(self, **kwargs)
#      46 @functools.wraps(dataarray_plot.plot, assigned=("__doc__", "__annotations__"))
#      47 def __call__(self, **kwargs) -> Any:
# ---> 48     return dataarray_plot.plot(self._da, **kwargs)
#
# File c:\Users\karimba\Documents\Github\chap-GIS\.venv\Lib\site-packages\xarray\plot\dataarray_plot.py:316, in plot(darray, row, col, col_wrap, ax, hue, subplot_kws, **kwargs)
#     312     plotfunc = hist
#     314 kwargs["ax"] = ax
# --> 316 return plotfunc(darray, **kwargs)
#
# File c:\Users\karimba\Documents\Github\chap-GIS\.venv\Lib\site-packages\xarray\plot\dataarray_plot.py:1582, in _plot2d.<locals>.newplotfunc(***failed resolving arguments***)
#    1578 yplt, ylab_extra = _resolve_intervals_2dplot(yvalnp, plotfunc.__name__)
#    1580 _ensure_plottable(xplt, yplt, zval)
# -> 1582 cmap_params, cbar_kwargs = _process_cmap_cbar_kwargs(
#    1583     plotfunc,
#    1584     zval.data,
#    1585     **locals(),
#    1586     _is_facetgrid=kwargs.pop("_is_facetgrid", False),
#    1587 )
#    1589 if "contour" in plotfunc.__name__:
#    1590     # extend is a keyword argument only for contour and contourf, but
#    1591     # passing it to the colorbar is sufficient for imshow and
#    1592     # pcolormesh
#    1593     kwargs["extend"] = cmap_params["extend"]
#
# File c:\Users\karimba\Documents\Github\chap-GIS\.venv\Lib\site-packages\xarray\plot\utils.py:956, in _process_cmap_cbar_kwargs(func, data, cmap, colors, cbar_kwargs, levels, _is_facetgrid, **kwargs)
#     954 cmap_kwargs.update((a, kwargs[a]) for a in cmap_args if a in kwargs)
#     955 if not _is_facetgrid:
# --> 956     cmap_params = _determine_cmap_params(**cmap_kwargs)
#     957 else:
#     958     cmap_params = {
#     959         k: cmap_kwargs[k]
#     960         for k in ["vmin", "vmax", "cmap", "extend", "levels", "norm"]
#     961     }
#
# File c:\Users\karimba\Documents\Github\chap-GIS\.venv\Lib\site-packages\xarray\plot\utils.py:190, in _determine_cmap_params(plot_data, vmin, vmax, cmap, center, robust, extend, levels, filled, norm, _is_facetgrid)
#     188     import matplotlib as mpl
#     189 else:
# --> 190     mpl = attempt_import("matplotlib")
#     192 if isinstance(levels, Iterable):
#     193     levels = sorted(levels)
#
# File c:\Users\karimba\Documents\Github\chap-GIS\.venv\Lib\site-packages\xarray\core\utils.py:1379, in attempt_import(module)
#    1377 reason = package_purpose.get(package_name, "")
#    1378 try:
# -> 1379     return importlib.import_module(module)
#    1380 except ImportError as e:
#    1381     raise ImportError(
#    1382         f"The {install_name} package is required {reason}"
#    1383         " but could not be imported."
#    1384         " Please install it with your package manager (e.g. conda or pip)."
#    1385     ) from e
#
# File ~\AppData\Local\miniconda3\Lib\importlib\__init__.py:88, in import_module(name, package)
#      86             break
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1333, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:950, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:1023, in _LoaderBasics.exec_module(self, module)
#
# File <frozen importlib._bootstrap>:488, in _call_with_frames_removed(f, *args, **kwds)
#
# File c:\Users\karimba\Documents\Github\chap-GIS\.venv\Lib\site-packages\matplotlib\__init__.py:1299
#    1295     rcParams['backend_fallback'] = False
#    1298 if os.environ.get('MPLBACKEND'):
# -> 1299     rcParams['backend'] = os.environ.get('MPLBACKEND')
#    1302 def get_backend(*, auto_select=True):
#    1303     """
#    1304     Return the name of the current backend.
#    1305
#    (...)   1323     matplotlib.use
#    1324     """
#
# File c:\Users\karimba\Documents\Github\chap-GIS\.venv\Lib\site-packages\matplotlib\__init__.py:774, in RcParams.__setitem__(self, key, val)
#     772         cval = self.validate[key](val)
#     773     except ValueError as ve:
# --> 774         raise ValueError(f"Key {key}: {ve}") from None
#     775     self._set(key, cval)
#     776 except KeyError as err:
#
# ValueError: Key backend: 'module://matplotlib_inline.backend_inline' is not a valid value for backend; supported values are ['gtk3agg', 'gtk3cairo', 'gtk4agg', 'gtk4cairo', 'macosx', 'nbagg', 'notebook', 'qtagg', 'qtcairo', 'qt5agg', 'qt5cairo', 'tkagg', 'tkcairo', 'webagg', 'wx', 'wxagg', 'wxcairo', 'agg', 'cairo', 'pdf', 'pgf', 'ps', 'svg', 'template']

# %% [markdown]
# -------
# # OpenEO approach

# %%
import openeo

conn = openeo.connect("https://openeo.dataspace.copernicus.eu")
conn.authenticate_oidc()
# Out:
# Authenticated using refresh token.
# <Connection to 'https://openeo.dataspace.copernicus.eu/openeo/1.2/' with OidcBearerAuth>

# %%
for coll in conn.list_collections():
    print(coll)
# Out:
# {'description': 'Copernicus Global 30 meter Digital Elevation Model dataset.', 'extent': {'spatial': {'bbox': [[-180, -90, 180, 90]]}, 'temporal': {'interval': [['2010-12-12T00:00:00Z', '2015-01-16T00:00:00Z']]}}, 'id': 'COPERNICUS_30', 'keywords': ['Copernicus', 'ESA', 'Satellite', 'Global', 'DEM', 'EU', 'EC'], 'license': 'proprietary', 'links': [{'href': 'https://stac.dataspace.copernicus.eu/v1/collections/cop-dem-glo-30-dged-cog/items', 'rel': 'items', 'type': 'application/geo+json'}, {'href': 'https://stac.dataspace.copernicus.eu/v1/', 'rel': 'parent', 'type': 'application/json'}, {'href': 'https://stac.dataspace.copernicus.eu/v1/', 'rel': 'root', 'type': 'application/json'}, {'href': 'https://stac.dataspace.copernicus.eu/v1/collections/cop-dem-glo-30-dged-cog', 'rel': 'self', 'type': 'application/json'}, {'href': 'https://dataspace.copernicus.eu/sites/default/files/media/files/2025-06/copernicus_contributing_mission_data_access_v2_cop_dem_licenses.pdf', 'rel': 'license', 'title': 'Legal notice on the use of Copernicus DEM Data and Service Information', 'type': 'application/pdf'}, {'href': 'https://stac.dataspace.copernicus.eu/v1/collections/cop-dem-glo-30-dged-cog/queryables', 'rel': 'http://www.opengis.net/def/rel/ogc/1.0/queryables', 'title': 'Queryables', 'type': 'application/schema+json'}], 'providers': [{'name': 'ESA', 'roles': ['producer'], 'url': 'https://dataspace.copernicus.eu/explore-data/data-collections/copernicus-contributing-missions/collections-description/COP-DEM'}, {'name': 'European Commission', 'roles': ['licensor'], 'url': 'https://commission.europa.eu/'}, {'name': 'CloudFerro', 'roles': ['host', 'processor'], 'url': 'https://cloudferro.com/'}], 'stac_extensions': ['https://stac-extensions.github.io/alternate-assets/v1.2.0/schema.json', 'https://stac-extensions.github.io/authentication/v1.1.0/schema.json', 'https://stac-extensions.github.io/processing/v1.2.0/schema.json', 'https://stac-extensions.github.io/projection/v2.0.0/schema.json', 'https://stac-extensions.github.io/sat/v1.1.0/schema.json', 'https://stac-extensions.github.io/scientific/v1.0.0/schema.json', 'https://stac-extensions.github.io/storage/v2.0.0/schema.json'], 'stac_version': '1.1.0', 'title': 'Copernicus Global 30 meter Digital Elevation Model dataset.'}
# {'description': 'Sentinel 3 imagery captured by OLCI sensor', 'extent': {'spatial': {'bbox': [[-180.0, -85.0, 180.0, 85.0]]}, 'temporal': {'interval': [['2016-04-17T11:33:13Z', None]]}}, 'id': 'SENTINEL3_OLCI_L1B', 'license': 'proprietary', 'links': [{'href': 'https://sh.dataspace.copernicus.eu/catalog/v1/', 'rel': 'root', 'type': 'application/json'}, {'href': 'https://sh.dataspace.copernicus.eu/catalog/v1/collections/sentinel-3-olci', 'rel': 'self', 'type': 'application/json'}, {'href': 'https://sh.dataspace.copernicus.eu/catalog/v1/collections', 'rel': 'parent', 'type': 'application/json'}, {'href': 'https://sh.dataspace.copernicus.eu/catalog/v1/collections/sentinel-3-olci/queryables', 'rel': 'http://www.opengis.net/def/rel/ogc/1.0/queryables', 'type': 'application/schema+json'}, {'href': 'https://sh.dataspace.copernicus.eu/catalog/v1/collections/sentinel-3-olci/items', 'rel': 'items', 'type': 'application/geo+json'}], 'providers': [], 'stac_extensions': ['https://stac-extensions.github.io/scientific/v1.0.0/schema.json', 'https://stac-extensions.github.io/sat/v1.0.0/schema.json', 'https://stac-extensions.github.io/eo/v1.0.0/schema.json'], 'stac_version': '1.0.0', 'title': 'Sentinel 3 OLCI'}
# {'description': 'Sentinel 3 imagery captured by SLSTR sensor', 'extent': {'spatial': {'bbox': [[-180.0, -85.0, 180.0, 85.0]]}, 'temporal': {'interval': [['2016-04-17T11:33:13Z', None]]}}, 'id': 'SENTINEL3_SLSTR', 'license': 'proprietary', 'links': [{'href': 'https://sh.dataspace.copernicus.eu/catalog/v1/', 'rel': 'root', 'type': 'application/json'}, {'href': 'https://sh.dataspace.copernicus.eu/catalog/v1/collections/sentinel-3-slstr', 'rel': 'self', 'type': 'application/json'}, {'href': 'https://sh.dataspace.copernicus.eu/catalog/v1/collections', 'rel': 'parent', 'type': 'application/json'}, {'href': 'https://sh.dataspace.copernicus.eu/catalog/v1/collections/sentinel-3-slstr/queryables', 'rel': 'http://www.opengis.net/def/rel/ogc/1.0/queryables', 'type': 'application/schema+json'}, {'href': 'https://sh.dataspace.copernicus.eu/catalog/v1/collections/sentinel-3-slstr/items', 'rel': 'items', 'type': 'application/geo+json'}], 'providers': [], 'stac_extensions': ['https://stac-extensions.github.io/scientific/v1.0.0/schema.json', 'https://stac-extensions.github.io/sat/v1.0.0/schema.json', 'https://stac-extensions.github.io/eo/v1.0.0/schema.json'], 'stac_version': '1.0.0', 'title': 'Sentinel 3 SLSTR'}
# {'description': 'Sentinel 5 Precursor imagery captured by TROPOMI sensor.\n\nThis dataset only supports loading one band at a time.', 'extent': {'spatial': {'bbox': [[-180.0, -85.0, 180.0, 85.0]]}, 'temporal': {'interval': [['2018-04-30T00:18:50Z', None]]}}, 'id': 'SENTINEL_5P_L2', 'license': 'proprietary', 'links': [{'href': 'https://sh.dataspace.copernicus.eu/catalog/v1/', 'rel': 'root', 'type': 'application/json'}, {'href': 'https://sh.dataspace.copernicus.eu/catalog/v1/collections/sentinel-5p-l2', 'rel': 'self', 'type': 'application/json'}, {'href': 'https://sh.dataspace.copernicus.eu/catalog/v1/collections', 'rel': 'parent', 'type': 'application/json'}, {'href': 'https://sh.dataspace.copernicus.eu/catalog/v1/collections/sentinel-5p-l2/queryables', 'rel': 'http://www.opengis.net/def/rel/ogc/1.0/queryables', 'type': 'application/schema+json'}, {'href': 'https://sh.dataspace.copernicus.eu/catalog/v1/collections/sentinel-5p-l2/items', 'rel': 'items', 'type': 'application/geo+json'}], 'providers': [], 'stac_extensions': ['https://stac-extensions.github.io/scientific/v1.0.0/schema.json', 'https://stac-extensions.github.io/sat/v1.0.0/schema.json', 'https://docs.sentinel-hub.com/api/latest/stac/s5p/v1.0.0/schema.json'], 'stac_version': '1.0.0', 'title': 'Sentinel 5 Precursor'}
# {'description': 'Global, cloud-free, and reconstructed historical Landsat spectral bands are provided at a spatial resolution of 30 meters and temporal resolution of bimonthly intervals from 1997 onwards. The dataset was generated using the GLAD Landsat ARD version 2 as the primary input for temporal aggregation and the imputation of missing values.', 'extent': {'spatial': {'bbox': [[-180, -90, 180, 90]]}, 'temporal': {'interval': [['1997-01-01T00:00:00Z', '2024-12-31T00:00:00Z']]}}, 'id': 'LANDSAT_BIMONTHLY_MOSAIC', 'keywords': ['Landsat', 'Mosaic', 'Time-series', 'Global'], 'license': 'other', 'links': [{'href': 'https://stac.dataspace.copernicus.eu/v1/collections/opengeohub-landsat-bimonthly-mosaic-v1.0.1/items', 'rel': 'items', 'type': 'application/geo+json'}, {'href': 'https://stac.dataspace.copernicus.eu/v1/', 'rel': 'parent', 'type': 'application/json'}, {'href': 'https://stac.dataspace.copernicus.eu/v1/', 'rel': 'root', 'type': 'application/json'}, {'href': 'https://stac.dataspace.copernicus.eu/v1/collections/opengeohub-landsat-bimonthly-mosaic-v1.0.1', 'rel': 'self', 'type': 'application/json'}, {'href': 'https://www.usgs.gov/faqs/are-there-any-restrictions-use-or-redistribution-landsat-data', 'rel': 'license', 'title': 'Landsat data policy', 'type': 'text/html'}, {'href': 'https://stac.dataspace.copernicus.eu/v1/collections/opengeohub-landsat-bimonthly-mosaic-v1.0.1/queryables', 'rel': 'http://www.opengis.net/def/rel/ogc/1.0/queryables', 'title': 'Queryables', 'type': 'application/schema+json'}], 'providers': [{'name': 'USGS', 'roles': ['producer'], 'url': 'https://www.usgs.gov/'}, {'name': 'OpenGeoHub', 'roles': ['processor'], 'url': 'https://opengeohub.org/'}, {'name': 'CloudFerro', 'roles': ['host'], 'url': 'https://cloudferro.com/'}], 'stac_extensions': ['https://stac-extensions.github.io/alternate-assets/v1.2.0/schema.json', 'https://stac-extensions.github.io/authentication/v1.1.0/schema.json', 'https://stac-extensions.github.io/processing/v1.2.0/schema.json', 'https://stac-extensions.github.io/projection/v2.0.0/schema.json', 'https://stac-extensions.github.io/scientific/v1.0.0/schema.json', 'https://stac-extensions.github.io/storage/v2.0.0/schema.json'], 'stac_version': '1.1.0', 'title': 'Landsat mosaic (bi-monthly, v1.0.1)'}
# {'description': '[EXPERIMENTAL] Copernicus High Resolution Land Vegetation Phenology and Productivity parameters at 10m on yearly basis from 2017 onwards for EU countries. This collection contains parameters of the first detected growing season.', 'extent': {'spatial': {'bbox': [[-62.0760771, -21.7894746, 56.138312, 72.0995811]]}, 'temporal': {'interval': [['2017-01-01T00:00:00Z', '2024-12-31T23:59:59Z']]}}, 'id': 'COPERNICUS_VEGETATION_PHENOLOGY_PRODUCTIVITY_10M_SEASON1', 'keywords': ['PPI', 'index', 'land', 'vegetation', 'plant', 'phenology', 'productivity', 'growing season', 'sentinel'], 'license': 'proprietary', 'links': [{'href': 'https://stac.openeo.vito.be/collections/copernicus_r_utm-wgs84_10_m_hrvpp-vpp_p_2017-now_v01/aggregate', 'rel': 'aggregate', 'type': 'application/json'}, {'href': 'https://stac.openeo.vito.be/collections/copernicus_r_utm-wgs84_10_m_hrvpp-vpp_p_2017-now_v01/aggregations', 'rel': 'aggregations', 'type': 'application/json'}, {'href': 'https://stac.openeo.vito.be/collections/copernicus_r_utm-wgs84_10_m_hrvpp-vpp_p_2017-now_v01/items', 'rel': 'items', 'type': 'application/geo+json'}, {'href': 'https://stac.openeo.vito.be/', 'rel': 'parent', 'type': 'application/json'}, {'href': 'https://stac.openeo.vito.be/collections/copernicus_r_utm-wgs84_10_m_hrvpp-vpp_p_2017-now_v01/queryables', 'rel': 'queryables', 'type': 'application/schema+json'}, {'href': 'https://stac.openeo.vito.be/', 'rel': 'root', 'type': 'application/json'}, {'href': 'https://stac.openeo.vito.be/collections/copernicus_r_utm-wgs84_10_m_hrvpp-vpp_p_2017-now_v01', 'rel': 'self', 'type': 'application/json'}, {'href': 'https://openeo.dataspace.copernicus.eu/openeo/1.2/collections/COPERNICUS_VEGETATION_PHENOLOGY_PRODUCTIVITY_10M_SEASON1/queryables', 'rel': 'http://www.opengis.net/def/rel/ogc/1.0/queryables', 'type': 'application/schema+json'}], 'providers': [{'name': 'VITO', 'roles': ['licensor', 'producer', 'processor'], 'url': 'https://www.vito.be/'}], 'stac_extensions': ['https://stac-extensions.github.io/item-assets/v1.0.0/schema.json', 'https://stac-extensions.github.io/raster/v1.1.0/schema.json', 'https://stac-extensions.github.io/eo/v1.1.0/schema.json'], 'stac_version': '1.0.0', 'title': 'Vegetation Phenology and Productivity parameters, yearly, UTM projection'}
# {'description': '[EXPERIMENTAL] Copernicus High Resolution Land Vegetation Phenology and Productivity parameters at 10m on yearly basis from 2017 onwards for EU countries. This collection contains parameters for season 2.', 'extent': {'spatial': {'bbox': [[-62.0760771, -21.7894746, 56.138312, 72.0995811]]}, 'temporal': {'interval': [['2017-01-01T00:00:00Z', '2024-12-31T23:59:59Z']]}}, 'id': 'COPERNICUS_VEGETATION_PHENOLOGY_PRODUCTIVITY_10M_SEASON2', 'keywords': ['PPI', 'index', 'land', 'vegetation', 'plant', 'phenology', 'productivity', 'growing season', 'sentinel'], 'license': 'proprietary', 'links': [{'href': 'https://stac.openeo.vito.be/collections/copernicus_r_utm-wgs84_10_m_hrvpp-vpp_p_2017-now_v01/aggregate', 'rel': 'aggregate', 'type': 'application/json'}, {'href': 'https://stac.openeo.vito.be/collections/copernicus_r_utm-wgs84_10_m_hrvpp-vpp_p_2017-now_v01/aggregations', 'rel': 'aggregations', 'type': 'application/json'}, {'href': 'https://stac.openeo.vito.be/collections/copernicus_r_utm-wgs84_10_m_hrvpp-vpp_p_2017-now_v01/items', 'rel': 'items', 'type': 'application/geo+json'}, {'href': 'https://stac.openeo.vito.be/', 'rel': 'parent', 'type': 'application/json'}, {'href': 'https://stac.openeo.vito.be/collections/copernicus_r_utm-wgs84_10_m_hrvpp-vpp_p_2017-now_v01/queryables', 'rel': 'queryables', 'type': 'application/schema+json'}, {'href': 'https://stac.openeo.vito.be/', 'rel': 'root', 'type': 'application/json'}, {'href': 'https://stac.openeo.vito.be/collections/copernicus_r_utm-wgs84_10_m_hrvpp-vpp_p_2017-now_v01', 'rel': 'self', 'type': 'application/json'}, {'href': 'https://openeo.dataspace.copernicus.eu/openeo/1.2/collections/COPERNICUS_VEGETATION_PHENOLOGY_PRODUCTIVITY_10M_SEASON2/queryables', 'rel': 'http://www.opengis.net/def/rel/ogc/1.0/queryables', 'type': 'application/schema+json'}], 'providers': [{'name': 'VITO', 'roles': ['licensor', 'producer', 'processor'], 'url': 'https://www.vito.be/'}], 'stac_extensions': ['https://stac-extensions.github.io/item-assets/v1.0.0/schema.json', 'https://stac-extensions.github.io/raster/v1.1.0/schema.json', 'https://stac-extensions.github.io/eo/v1.1.0/schema.json'], 'stac_version': '1.0.0', 'title': 'Vegetation Phenology and Productivity parameters, yearly, UTM projection'}
# {'description': '[EXPERIMENTAL] Plant phenology index (PPI) at 10m resolution for EU.', 'extent': {'spatial': {'bbox': [[-62.0760771, -21.7894746, 56.138312, 72.0995811]]}, 'temporal': {'interval': [['2017-01-01T00:00:00Z', None]]}}, 'id': 'COPERNICUS_PLANT_PHENOLOGY_INDEX', 'keywords': ['PPI', 'index', 'land', 'vegetation', 'plant', 'phenology', 'growing season', 'productivity', 'sentinel'], 'license': 'proprietary', 'links': [{'href': 'https://stac.openeo.vito.be/collections/copernicus_r_utm-wgs84_10_m_hrvpp-st_p_2017-now_v01/aggregate', 'rel': 'aggregate', 'type': 'application/json'}, {'href': 'https://stac.openeo.vito.be/collections/copernicus_r_utm-wgs84_10_m_hrvpp-st_p_2017-now_v01/aggregations', 'rel': 'aggregations', 'type': 'application/json'}, {'href': 'https://stac.openeo.vito.be/collections/copernicus_r_utm-wgs84_10_m_hrvpp-st_p_2017-now_v01/items', 'rel': 'items', 'type': 'application/geo+json'}, {'href': 'https://stac.openeo.vito.be/', 'rel': 'parent', 'type': 'application/json'}, {'href': 'https://stac.openeo.vito.be/collections/copernicus_r_utm-wgs84_10_m_hrvpp-st_p_2017-now_v01/queryables', 'rel': 'queryables', 'type': 'application/schema+json'}, {'href': 'https://stac.openeo.vito.be/', 'rel': 'root', 'type': 'application/json'}, {'href': 'https://stac.openeo.vito.be/collections/copernicus_r_utm-wgs84_10_m_hrvpp-st_p_2017-now_v01', 'rel': 'self', 'type': 'application/json'}, {'href': 'https://www.eea.europa.eu/en/datahub/datahubitem-view/b967dae7-783b-44eb-a3eb-727e3b8fc060', 'rel': 'describedby', 'title': 'EEA Data hub', 'type': 'text/html'}, {'href': 'https://doi.org/10.2909/2d8ef180-584b-4283-929b-4e3af40c1847', 'rel': 'cite-as', 'title': 'DOI', 'type': 'text/html'}, {'href': 'https://openeo.dataspace.copernicus.eu/openeo/1.2/collections/COPERNICUS_PLANT_PHENOLOGY_INDEX/queryables', 'rel': 'http://www.opengis.net/def/rel/ogc/1.0/queryables', 'type': 'application/schema+json'}], 'providers': [{'name': 'European Environment Agency', 'roles': ['licensor'], 'url': 'https://land.copernicus.eu'}, {'name': 'VITO', 'roles': ['processor', 'producer'], 'url': 'https://www.vito.be/'}], 'stac_extensions': ['https://stac-extensions.github.io/item-assets/v1.0.0/schema.json', 'https://stac-extensions.github.io/raster/v1.1.0/schema.json', 'https://stac-extensions.github.io/classification/v1.0.0/schema.json'], 'stac_version': '1.0.0', 'title': 'Seasonal PPI Trajectories, 10-daily, UTM projection'}
# {'description': 'WorldCover provides global land cover products for 2020 at 10 m resolution, developed and validated in near-real time based on Sentinel-1 and Sentinel-2 data. ', 'extent': {'spatial': {'bbox': [[-180.0, -60.0, 180.0, 84.0]]}, 'temporal': {'interval': [['2020-01-01T00:00:00Z', '2020-12-31T23:59:59Z']]}}, 'id': 'ESA_WORLDCOVER_10M_2020_V1', 'keywords': ['VITO', 'COPERNICUS', 'ESA', 'Land Cover', 'Sentinel-1', 'Sentinel-2', 'Environment', 'WorldCover'], 'license': 'CC-BY-4.0', 'links': [{'href': 'https://esa-worldcover.org/', 'rel': 'alternate', 'title': 'Product website'}, {'href': 'https://services.terrascope.be/catalogue/description?collection=urn:eop:VITO:ESA_WorldCover_10m_2020_V1', 'rel': 'alternate', 'title': 'EO OpenSearch catalog'}, {'href': 'https://viewer.esa-worldcover.org/worldcover', 'rel': 'alternate', 'title': 'Product Viewer'}, {'href': 'https://services.terrascope.be/wmts/v2', 'rel': 'wmts', 'wmts:layer': 'WORLDCOVER_2020_MAP'}, {'href': 'https://openeo.dataspace.copernicus.eu/openeo/1.2/collections', 'rel': 'root'}, {'href': 'https://openeo.dataspace.copernicus.eu/openeo/1.2/collections', 'rel': 'parent'}, {'href': 'https://openeo.dataspace.copernicus.eu/openeo/1.2/collections/ESA_WORLDCOVER_10M_2020_V1', 'rel': 'self'}, {'href': 'https://openeo.dataspace.copernicus.eu/openeo/1.2/collections/ESA_WORLDCOVER_10M_2020_V1/queryables', 'rel': 'http://www.opengis.net/def/rel/ogc/1.0/queryables', 'type': 'application/schema+json'}], 'providers': [{'name': 'VITO', 'roles': ['producer'], 'url': 'https://remotesensing.vito.be/'}, {'name': 'ESA', 'roles': ['licensor'], 'url': 'https://esa.int/'}], 'stac_extensions': ['https://stac-extensions.github.io/raster/v1.1.0/schema.json', 'https://stac-extensions.github.io/eo/v1.1.0/schema.json'], 'stac_version': '1.1.0', 'title': 'Global landcover at 10m resolution for 2020.'}
# {'description': 'WorldCover provides global land cover products for 2021 at 10 m resolution, developed and validated in near-real time based on Sentinel-1 and Sentinel-2 data. ', 'extent': {'spatial': {'bbox': [[-180.0, -60.0, 180.0, 84.0]]}, 'temporal': {'interval': [['2021-01-01T00:00:00Z', '2021-12-31T23:59:59Z']]}}, 'id': 'ESA_WORLDCOVER_10M_2021_V2', 'keywords': ['VITO', 'COPERNICUS', 'ESA', 'Land Cover', 'Sentinel-1', 'Sentinel-2', 'Environment', 'WorldCover'], 'license': 'CC-BY-4.0', 'links': [{'href': 'https://esa-worldcover.org/', 'rel': 'alternate', 'title': 'Product website'}, {'href': 'https://services.terrascope.be/catalogue/description?collection=urn:eop:VITO:ESA_WorldCover_10m_2021_V2', 'rel': 'alternate', 'title': 'EO OpenSearch catalog'}, {'href': 'https://viewer.esa-worldcover.org/worldcover', 'rel': 'alternate', 'title': 'Product Viewer'}, {'href': 'https://services.terrascope.be/wmts/v2', 'rel': 'wmts', 'wmts:layer': 'WORLDCOVER_2021_MAP'}, {'href': 'https://openeo.dataspace.copernicus.eu/openeo/1.2/collections', 'rel': 'root'}, {'href': 'https://openeo.dataspace.copernicus.eu/openeo/1.2/collections', 'rel': 'parent'}, {'href': 'https://openeo.dataspace.copernicus.eu/openeo/1.2/collections/ESA_WORLDCOVER_10M_2021_V2', 'rel': 'self'}, {'href': 'https://openeo.dataspace.copernicus.eu/openeo/1.2/collections/ESA_WORLDCOVER_10M_2021_V2/queryables', 'rel': 'http://www.opengis.net/def/rel/ogc/1.0/queryables', 'type': 'application/schema+json'}], 'providers': [{'name': 'VITO', 'roles': ['producer'], 'url': 'https://remotesensing.vito.be/'}, {'name': 'ESA', 'roles': ['licensor'], 'url': 'https://esa.int/'}], 'stac_extensions': ['https://stac-extensions.github.io/raster/v1.1.0/schema.json', 'https://stac-extensions.github.io/eo/v1.1.0/schema.json'], 'stac_version': '1.1.0', 'title': 'Global landcover at 10m resolution for 2021.'}
# {'description': '[EXPERIMENTAL] Sentinel-1 monthly mosaics are generated from monthly stacks of Sentinel-1 GRD data by calculating the weighted sum of the terrain corrected backscatter observations. Two different Sentinel-1 mosaics are being produced for each month: IW mosaic and DH mosaic.', 'extent': {'spatial': {'bbox': [[-180, -90, 180, 90]]}, 'temporal': {'interval': [['2020-01-01T00:00:00Z', None]]}}, 'id': 'SENTINEL1_GLOBAL_MOSAICS', 'keywords': ['raster', 'systematic', 'satellite imagery', 'SAR', 'radar', 'backscattering', 'polarization', 'Copernicus', 'maritime monitoring', 'land monitoring', 'disaster response', 'open data'], 'license': 'other', 'links': [{'href': 'https://stac.dataspace.copernicus.eu/v1/collections/sentinel-1-global-mosaics/items', 'rel': 'items', 'type': 'application/geo+json'}, {'href': 'https://stac.dataspace.copernicus.eu/v1/', 'rel': 'parent', 'type': 'application/json'}, {'href': 'https://stac.dataspace.copernicus.eu/v1/', 'rel': 'root', 'type': 'application/json'}, {'href': 'https://stac.dataspace.copernicus.eu/v1/collections/sentinel-1-global-mosaics', 'rel': 'self', 'type': 'application/json'}, {'href': 'https://sentinels.copernicus.eu/documents/247904/690755/Sentinel_Data_Legal_Notice', 'rel': 'license', 'title': 'Legal notice on the use of Copernicus Sentinel Data and Service Information', 'type': 'application/pdf'}, {'href': 'https://stac.dataspace.copernicus.eu/v1/collections/sentinel-1-global-mosaics/queryables', 'rel': 'http://www.opengis.net/def/rel/ogc/1.0/queryables', 'title': 'Queryables', 'type': 'application/schema+json'}], 'providers': [{'name': 'ESA', 'roles': ['producer'], 'url': 'https://sentinels.copernicus.eu/web/sentinel/copernicus/sentinel-1'}, {'name': 'European Commission', 'roles': ['licensor'], 'url': 'https://commission.europa.eu/'}, {'name': 'CloudFerro', 'roles': ['host', 'processor'], 'url': 'https://cloudferro.com/'}], 'stac_extensions': ['https://stac-extensions.github.io/authentication/v1.1.0/schema.json', 'https://stac-extensions.github.io/projection/v2.0.0/schema.json', 'https://stac-extensions.github.io/processing/v1.2.0/schema.json', 'https://stac-extensions.github.io/product/v0.1.0/schema.json', 'https://stac-extensions.github.io/scientific/v1.0.0/schema.json', 'https://stac-extensions.github.io/alternate-assets/v1.2.0/schema.json', 'https://stac-extensions.github.io/sar/v1.1.0/schema.json', 'https://stac-extensions.github.io/storage/v2.0.0/schema.json'], 'stac_version': '1.1.0', 'title': 'Sentinel 1 Monthly Mosaics'}
# {'description': 'SENTINEL-2 is a wide-swath, high-resolution, multi-spectral imaging mission, supporting Copernicus Land Monitoring studies, including the monitoring of vegetation, soil and water cover, as well as observation of inland waterways and coastal areas. The SENTINEL-2 Multispectral Instrument (MSI) samples 13 spectral bands: four bands at 10 metres, six bands at 20 metres and three bands at 60 metres spatial resolution.\n The level 2A data is atmospherically corrected using Sen2Cor.', 'extent': {'spatial': {'bbox': [[-180, -90, 180, 90]]}, 'temporal': {'interval': [['2015-06-27T10:25:31Z', None]]}}, 'id': 'SENTINEL2_L2A', 'keywords': ['COPERNICUS', 'ESA', 'Orthoimagery', 'Sentinel-2', 'MSI', 'Level-2A', 'Radiometry', 'Plant Resource', 'TOC'], 'license': 'other', 'links': [{'href': 'https://stac.dataspace.copernicus.eu/v1/collections/sentinel-2-l2a/items', 'rel': 'items', 'type': 'application/geo+json'}, {'href': 'https://stac.dataspace.copernicus.eu/v1/', 'rel': 'parent', 'type': 'application/json'}, {'href': 'https://stac.dataspace.copernicus.eu/v1/', 'rel': 'root', 'type': 'application/json'}, {'href': 'https://stac.dataspace.copernicus.eu/v1/collections/sentinel-2-l2a', 'rel': 'self', 'type': 'application/json'}, {'href': 'https://sentinels.copernicus.eu/documents/247904/690755/Sentinel_Data_Legal_Notice', 'rel': 'license', 'title': 'Legal notice on the use of Copernicus Sentinel Data and Service Information', 'type': 'application/pdf'}, {'href': 'https://ceos.org/ard/files/PFS/SR/v5.0.1/CEOS-ARD_Product_Family_Specification_Surface_Reflectance-v5.0.1.docx', 'rel': 'ceos-ard-specification', 'title': 'CEOS-ARD Product Specification for Surface Reflectance (Word)', 'type': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document'}, {'href': 'https://ceos.org/ard/files/PFS/SR/v5.0.1/CEOS-ARD_Product_Family_Specification_Surface_Reflectance-v5.0.1.pdf', 'rel': 'ceos-ard-specification', 'title': 'CEOS-ARD Product Specification for Surface Reflectance (PDF)', 'type': 'application/pdf'}, {'href': 'https://stac.dataspace.copernicus.eu/v1/collections/sentinel-2-l2a/queryables', 'rel': 'http://www.opengis.net/def/rel/ogc/1.0/queryables', 'title': 'Queryables', 'type': 'application/schema+json'}], 'providers': [{'name': 'ESA', 'roles': ['producer'], 'url': 'https://sentinels.copernicus.eu/web/sentinel/copernicus/sentinel-2'}, {'name': 'European Commission', 'roles': ['licensor'], 'url': 'https://commission.europa.eu/'}, {'name': 'CloudFerro', 'roles': ['host', 'processor'], 'url': 'https://cloudferro.com/'}], 'stac_extensions': ['https://stac-extensions.github.io/eo/v2.0.0/schema.json', 'https://stac-extensions.github.io/authentication/v1.1.0/schema.json', 'https://stac-extensions.github.io/projection/v2.0.0/schema.json', 'https://stac-extensions.github.io/processing/v1.2.0/schema.json', 'https://stac-extensions.github.io/product/v0.1.0/schema.json', 'https://stac-extensions.github.io/scientific/v1.0.0/schema.json', 'https://stac-extensions.github.io/alternate-assets/v1.2.0/schema.json', 'https://stac-extensions.github.io/raster/v2.0.0/schema.json', 'https://stac-extensions.github.io/sat/v1.1.0/schema.json', 'https://stac-extensions.github.io/classification/v2.0.0/schema.json', 'https://stac-extensions.github.io/ceos-ard/v0.2.0/schema.json', 'https://stac-extensions.github.io/storage/v2.0.0/schema.json'], 'stac_version': '1.1.0', 'title': 'Sentinel-2 L2A'}
# {'description': 'SENTINEL-2 is a wide-swath, high-resolution, multi-spectral imaging mission, supporting Copernicus Land Monitoring studies, including the monitoring of vegetation, soil and water cover, as well as observation of inland waterways and coastal areas. The SENTINEL-2 Multispectral Instrument (MSI) samples 13 spectral bands: four bands at 10 metres, six bands at 20 metres and three bands at 60 metres spatial resolution.', 'extent': {'spatial': {'bbox': [[-180, -90, 180, 90]]}, 'temporal': {'interval': [['2015-06-27T10:25:31Z', None]]}}, 'id': 'SENTINEL2_L1C', 'keywords': ['Copernicus', 'Sentinel', 'EU', 'ESA', 'Satellite', 'Global', 'Imagery', 'Reflectance'], 'license': 'other', 'links': [{'href': 'https://stac.dataspace.copernicus.eu/v1/collections/sentinel-2-l1c/items', 'rel': 'items', 'type': 'application/geo+json'}, {'href': 'https://stac.dataspace.copernicus.eu/v1/', 'rel': 'parent', 'type': 'application/json'}, {'href': 'https://stac.dataspace.copernicus.eu/v1/', 'rel': 'root', 'type': 'application/json'}, {'href': 'https://stac.dataspace.copernicus.eu/v1/collections/sentinel-2-l1c', 'rel': 'self', 'type': 'application/json'}, {'href': 'https://sentinels.copernicus.eu/documents/247904/690755/Sentinel_Data_Legal_Notice', 'rel': 'license', 'title': 'Legal notice on the use of Copernicus Sentinel Data and Service Information', 'type': 'application/pdf'}, {'href': 'https://stac.dataspace.copernicus.eu/v1/collections/sentinel-2-l1c/queryables', 'rel': 'http://www.opengis.net/def/rel/ogc/1.0/queryables', 'title': 'Queryables', 'type': 'application/schema+json'}], 'providers': [{'name': 'ESA', 'roles': ['producer'], 'url': 'https://sentinels.copernicus.eu/web/sentinel/copernicus/sentinel-2'}, {'name': 'European Commission', 'roles': ['licensor'], 'url': 'https://commission.europa.eu/'}, {'name': 'CloudFerro', 'roles': ['host', 'processor'], 'url': 'https://cloudferro.com/'}], 'stac_extensions': ['https://stac-extensions.github.io/eo/v2.0.0/schema.json', 'https://stac-extensions.github.io/authentication/v1.1.0/schema.json', 'https://stac-extensions.github.io/projection/v2.0.0/schema.json', 'https://stac-extensions.github.io/processing/v1.2.0/schema.json', 'https://stac-extensions.github.io/product/v0.1.0/schema.json', 'https://stac-extensions.github.io/scientific/v1.0.0/schema.json', 'https://stac-extensions.github.io/alternate-assets/v1.2.0/schema.json', 'https://stac-extensions.github.io/raster/v2.0.0/schema.json', 'https://stac-extensions.github.io/sat/v1.1.0/schema.json', 'https://stac-extensions.github.io/storage/v2.0.0/schema.json'], 'stac_version': '1.1.0', 'title': 'Sentinel-2 L1C'}
# {'description': 'The Sentinel-1 mission provides data from a dual-polarization C-band Synthetic Aperture Radar (SAR) instrument. This collection includes the S1 Ground Range Detected (GRD) scenes, processed to a calibrated, ortho-corrected product. This collection is compatible with "sar_backscatter" and "ard_normalized_radar_backscatter" processes.', 'extent': {'spatial': {'bbox': [[0, 0, 0, 0]]}, 'temporal': {'interval': [[None, None]]}}, 'id': 'SENTINEL1_GRD', 'keywords': ['raster', 'systematic', 'satellite imagery', 'SAR', 'radar', 'backscattering', 'polarization', 'Copernicus', 'maritime monitoring', 'land monitoring', 'disaster response', 'open data'], 'license': 'proprietary', 'links': [{'href': 'https://openeo.dataspace.copernicus.eu/openeo/1.2/collections', 'rel': 'root'}, {'href': 'https://openeo.dataspace.copernicus.eu/openeo/1.2/collections', 'rel': 'parent'}, {'href': 'https://openeo.dataspace.copernicus.eu/openeo/1.2/collections/SENTINEL1_GRD', 'rel': 'self'}, {'href': 'https://openeo.dataspace.copernicus.eu/openeo/1.2/collections/SENTINEL1_GRD/queryables', 'rel': 'http://www.opengis.net/def/rel/ogc/1.0/queryables', 'type': 'application/schema+json'}], 'stac_extensions': ['https://stac-extensions.github.io/datacube/v2.2.0/schema.json', 'https://stac-extensions.github.io/eo/v1.1.0/schema.json'], 'stac_version': '0.9.0', 'title': 'Sentinel-1 SAR GRD: C-band Synthetic Aperture Radar Ground Range Detected.'}
# {'description': '[Experimental] Sentinel-3  SYNERGY products are created from a combination of OLCI and SLSTR Level-1B products (including both\nnadir and oblique views). The SYNERGY swath is then corresponding to the common area between OLCI\nand SLSTR swaths, restricted to the daylight part of the SENTINEL-3 orbit (i.e., where the sun zenith angle\nat satellite ground track is lower than 80°).\n ', 'extent': {'spatial': {'bbox': [[0, 0, 0, 0]]}, 'temporal': {'interval': [[None, None]]}}, 'id': 'SENTINEL3_SYN_L2_SYN', 'keywords': ['COPERNICUS', 'ESA', 'Sentinel-3', 'SYN'], 'license': 'proprietary', 'links': [{'href': 'https://openeo.dataspace.copernicus.eu/openeo/1.2/collections', 'rel': 'root'}, {'href': 'https://openeo.dataspace.copernicus.eu/openeo/1.2/collections', 'rel': 'parent'}, {'href': 'https://openeo.dataspace.copernicus.eu/openeo/1.2/collections/SENTINEL3_SYN_L2_SYN', 'rel': 'self'}, {'href': 'https://openeo.dataspace.copernicus.eu/openeo/1.2/collections/SENTINEL3_SYN_L2_SYN/queryables', 'rel': 'http://www.opengis.net/def/rel/ogc/1.0/queryables', 'type': 'application/schema+json'}], 'stac_extensions': ['https://stac-extensions.github.io/datacube/v2.2.0/schema.json', 'https://stac-extensions.github.io/eo/v1.1.0/schema.json'], 'stac_version': '0.9.0', 'title': 'Daily global Sentinel-3 Synergy products at 300m resolution combining OCLI and SLSTR bands.'}
# {'description': '*Experimental* Daily global Sentinel-3 land surface temperature at 1km resolution. Land surface temperature is defined as the effective radiometric temperature of the Earth\'s surface "skin" in the instrument field of view. Here, "skin" is referring to the top surface in bare soil conditions and to the effective emitting temperature of vegetation "canopies" as determined from a view of the top of a canopy.\n This product is derived from the SLSTR (Sea and Land Surface Temperature Radiometer) instrument on board the Sentinel-3 satellite.\n\n Multiple observations may be available per day, we recommend temporal aggregation to create daily composites. ', 'extent': {'spatial': {'bbox': [[0, 0, 0, 0]]}, 'temporal': {'interval': [[None, None]]}}, 'id': 'SENTINEL3_SLSTR_L2_LST', 'keywords': ['COPERNICUS', 'ESA', 'Sentinel-3', 'SLSTR'], 'license': 'proprietary', 'links': [{'href': 'https://openeo.dataspace.copernicus.eu/openeo/1.2/collections', 'rel': 'root'}, {'href': 'https://openeo.dataspace.copernicus.eu/openeo/1.2/collections', 'rel': 'parent'}, {'href': 'https://openeo.dataspace.copernicus.eu/openeo/1.2/collections/SENTINEL3_SLSTR_L2_LST', 'rel': 'self'}, {'href': 'https://openeo.dataspace.copernicus.eu/openeo/1.2/collections/SENTINEL3_SLSTR_L2_LST/queryables', 'rel': 'http://www.opengis.net/def/rel/ogc/1.0/queryables', 'type': 'application/schema+json'}], 'stac_extensions': ['https://stac-extensions.github.io/datacube/v2.2.0/schema.json', 'https://stac-extensions.github.io/eo/v1.1.0/schema.json'], 'stac_version': '0.9.0', 'title': 'Daily global Sentinel-3 Land surface temperature at 1km resolution'}
# {'description': 'This collection provides Sentinel-3 OLCI Level-2 Land Full Resolution products containing data on global vegetation, chlorophyll, and water vapor.', 'extent': {'spatial': {'bbox': [[0, 0, 0, 0]]}, 'temporal': {'interval': [[None, None]]}}, 'id': 'SENTINEL3_OLCI_L2_LAND', 'keywords': ['Sentinel', 'Copernicus', 'ESA', 'Satellite', 'Global', 'Land', 'Biomass'], 'license': 'proprietary', 'links': [{'href': 'https://openeo.dataspace.copernicus.eu/openeo/1.2/collections', 'rel': 'root'}, {'href': 'https://openeo.dataspace.copernicus.eu/openeo/1.2/collections', 'rel': 'parent'}, {'href': 'https://openeo.dataspace.copernicus.eu/openeo/1.2/collections/SENTINEL3_OLCI_L2_LAND', 'rel': 'self'}, {'href': 'https://openeo.dataspace.copernicus.eu/openeo/1.2/collections/SENTINEL3_OLCI_L2_LAND/queryables', 'rel': 'http://www.opengis.net/def/rel/ogc/1.0/queryables', 'type': 'application/schema+json'}], 'stac_extensions': ['https://stac-extensions.github.io/datacube/v2.2.0/schema.json', 'https://stac-extensions.github.io/eo/v1.1.0/schema.json'], 'stac_version': '0.9.0', 'title': 'Sentinel-3 OLCI Land Full Resolution (NRT)'}
# {'description': 'OLCI Level 2 Marine products provide spectral information on the colour of the oceans (water reflectances). These radiometric products are used to estimate geophysical parameters e.g. estimates of phytoplankton biomass through determining the Chlorophyll-a (Chl) concentration. In coastal areas, they also allow monitoring of the sediment load via the Total Suspended Matter (TSM) product. Full resolution products are at a nominal 300m resolution.', 'extent': {'spatial': {'bbox': [[0, 0, 0, 0]]}, 'temporal': {'interval': [[None, None]]}}, 'id': 'SENTINEL3_OLCI_L2_WATER', 'keywords': ['Sentinel', 'Copernicus', 'ESA', 'Satellite', 'Global', 'Water', 'Ocean'], 'license': 'proprietary', 'links': [{'href': 'https://openeo.dataspace.copernicus.eu/openeo/1.2/collections', 'rel': 'root'}, {'href': 'https://openeo.dataspace.copernicus.eu/openeo/1.2/collections', 'rel': 'parent'}, {'href': 'https://openeo.dataspace.copernicus.eu/openeo/1.2/collections/SENTINEL3_OLCI_L2_WATER', 'rel': 'self'}, {'href': 'https://openeo.dataspace.copernicus.eu/openeo/1.2/collections/SENTINEL3_OLCI_L2_WATER/queryables', 'rel': 'http://www.opengis.net/def/rel/ogc/1.0/queryables', 'type': 'application/schema+json'}], 'stac_extensions': ['https://stac-extensions.github.io/datacube/v2.2.0/schema.json', 'https://stac-extensions.github.io/eo/v1.1.0/schema.json'], 'stac_version': '0.9.0', 'title': 'Sentinel-3 OLCI Water Full Resolution (NRT)'}
# {'description': 'This Collection provides the Sentinel-3 Synergy Level-2 Aerosol Optical Depth product, which is a downstream development of the Sentinel-2 Level-1 OLCI FR and SLSTR Radiances and Brightness Temperatures products. The dataset provides both retrieved and diagnostic global aerosol parameters at super-pixel (4.5 km x 4.5 km) resolution for all regions over land and ocean free of snow/ice cover, excluding high cloud fraction data.', 'extent': {'spatial': {'bbox': [[0, 0, 0, 0]]}, 'temporal': {'interval': [[None, None]]}}, 'id': 'SENTINEL3_SYN_L2_AOD', 'keywords': ['Sentinel', 'Copernicus', 'ESA', 'Satellite', 'Global', 'Atmosphere'], 'license': 'proprietary', 'links': [{'href': 'https://openeo.dataspace.copernicus.eu/openeo/1.2/collections', 'rel': 'root'}, {'href': 'https://openeo.dataspace.copernicus.eu/openeo/1.2/collections', 'rel': 'parent'}, {'href': 'https://openeo.dataspace.copernicus.eu/openeo/1.2/collections/SENTINEL3_SYN_L2_AOD', 'rel': 'self'}, {'href': 'https://openeo.dataspace.copernicus.eu/openeo/1.2/collections/SENTINEL3_SYN_L2_AOD/queryables', 'rel': 'http://www.opengis.net/def/rel/ogc/1.0/queryables', 'type': 'application/schema+json'}], 'stac_extensions': ['https://stac-extensions.github.io/datacube/v2.2.0/schema.json', 'https://stac-extensions.github.io/eo/v1.1.0/schema.json'], 'stac_version': '0.9.0', 'title': 'Sentinel-3 SYNERGY Aerosol Optical Depth'}

# %%
bbox = {
    "west": 10.5,
    "south": 59.9,
    "east": 10.6,
    "north": 60.0
}

wc = conn.load_collection(
    "ESA_WORLDCOVER_10M_2021_V2",
    spatial_extent=bbox,
)
wc.download('../data/cache/explore_worldcover.nc')

# %%
import xarray as xr
ds = xr.open_dataset('../data/cache/explore_worldcover.nc')
ds
# Out:
# <xarray.Dataset> Size: 6MB
# Dimensions:  (t: 1, y: 1200, x: 1200)
# Coordinates:
#   * t        (t) datetime64[ns] 8B 2021-01-01
#   * y        (y) float64 10kB 60.0 60.0 60.0 60.0 60.0 ... 59.9 59.9 59.9 59.9
#   * x        (x) float64 10kB 10.5 10.5 10.5 10.5 10.5 ... 10.6 10.6 10.6 10.6
# Data variables:
#     crs      |S1 1B ...
#     MAP      (t, y, x) float32 6MB ...
# Attributes:
#     Conventions:  CF-1.9
#     institution:  openEO platform

# %%
ds.MAP.values
# Out:
# array([[[10., 10., 10., ..., 10., 10., 10.],
#         [10., 10., 10., ..., 10., 10., 10.],
#         [10., 10., 10., ..., 10., 10., 10.],
#         ...,
#         [10., 10., 10., ..., 80., 80., 80.],
#         [10., 10., 10., ..., 80., 80., 80.],
#         [10., 10., 10., ..., 80., 80., 80.]]],
#       shape=(1, 1200, 1200), dtype=float32)

# %%
ds.MAP.plot()
